# %%
import numpy as np
import pandas as pd

from sentence_transformers import SentenceTransformer, util
import torch
import time
from bert_score import score
import itertools

import re

import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
df_fda = pd.read_csv('fda_cfr.csv')
fda_new = df_fda.copy()
print(fda_new.shape)
fda_new.head()
# Out:
# (8404, 5)
#                        FDA_Chapter                    FDA_Section     CFR  \
# 0  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.1"
# 1  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.3"
# 2  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.4"
# 3  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.20"
# 4  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.21"
#
#                                 FDA_Subpart  \
# 0                                  General.
# 1                              Definitions.
# 2                      Authority citations.
# 3  Presence of mandatory label information.
# 4         Failure to reveal material facts.
#
#                                      FDA_Description
# 0  (a) The provisions of regulations promulgated ...
# 1  (a)  Labeling   includes all written, printed,...
# 2  (a) For each part of its regulations, the Food...
# 3  In the regulations specified in 1.1(c) of this...
# 4  (a) Labeling of a food, drug, device, cosmetic...

# %%
# Reserved data
fda_reserved = fda_new.loc[fda_new['FDA_Subpart'] == '[Reserved]']
print(fda_reserved.shape)
fda_reserved.head()
# Out:
# (488, 5)
#      FDA_Chapter FDA_Section   CFR FDA_Subpart FDA_Description
# 998          NaN         NaN  "84"  [Reserved]             NaN
# 999          NaN         NaN  "85"  [Reserved]             NaN
# 1000         NaN         NaN  "86"  [Reserved]             NaN
# 1001         NaN         NaN  "87"  [Reserved]             NaN
# 1002         NaN         NaN  "88"  [Reserved]             NaN

# %%
# Extract Reserved regulations
cond = fda_new['FDA_Subpart'].isin(fda_reserved['FDA_Subpart'])
fda_new.drop(fda_new[cond].index, inplace = True)
fda_new.reset_index(drop=True, inplace=True)
print(fda_new.shape)
fda_new.head()
# Out:
# (7916, 5)
#                        FDA_Chapter                    FDA_Section     CFR  \
# 0  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.1"
# 1  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.3"
# 2  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.4"
# 3  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.20"
# 4  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.21"
#
#                                 FDA_Subpart  \
# 0                                  General.
# 1                              Definitions.
# 2                      Authority citations.
# 3  Presence of mandatory label information.
# 4         Failure to reveal material facts.
#
#                                      FDA_Description
# 0  (a) The provisions of regulations promulgated ...
# 1  (a)  Labeling   includes all written, printed,...
# 2  (a) For each part of its regulations, the Food...
# 3  In the regulations specified in 1.1(c) of this...
# 4  (a) Labeling of a food, drug, device, cosmetic...

# %%
print(fda_new.shape)
fda_new.isnull().sum()
# Out:
# (7916, 5)
# FDA_Chapter        0
# FDA_Section        0
# CFR                0
# FDA_Subpart        0
# FDA_Description    0
# dtype: int64

# %%
fda_new['fda_desc_cleaned'] = ''

# Pre-processing FDA Descriptions
lemmatizer = WordNetLemmatizer()
pattern1 = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
pattern2 = '[0-9]'
for i in range(0,len(fda_new)):
        sent_ref = fda_new.iloc[i]['FDA_Description']
        sent_ref = sent_ref.lower() # convert to lower case
        word_list = nltk.word_tokenize(sent_ref)
        sent_ref = ' '.join([lemmatizer.lemmatize(w) for w in word_list]) # lemmatize
        sent_ref = re.sub(r'\([^)]*\)', '', sent_ref) # remove characters which are within () and []
        sent_ref = pattern1.sub('', sent_ref) # remove stopwords
        sent_ref = re.sub(r'[^\w\s]','',sent_ref) # remove spaces (new line, tabs etc)
        sent_ref = re.sub(pattern2, '', sent_ref) # remove numbers
        sent_ref = " ".join(sent_ref.split()) # remove whitespaces, if any
        fda_new['fda_desc_cleaned'][i] = sent_ref
        
fda_new
# Out:
#                             FDA_Chapter  \
# 0       GENERAL ENFORCEMENT REGULATIONS
# 1       GENERAL ENFORCEMENT REGULATIONS
# 2       GENERAL ENFORCEMENT REGULATIONS
# 3       GENERAL ENFORCEMENT REGULATIONS
# 4       GENERAL ENFORCEMENT REGULATIONS
# ...                                 ...
# 7911  MANDATORY DECLASSIFICATION REVIEW
# 7912  MANDATORY DECLASSIFICATION REVIEW
# 7913  MANDATORY DECLASSIFICATION REVIEW
# 7914  MANDATORY DECLASSIFICATION REVIEW
# 7915  MANDATORY DECLASSIFICATION REVIEW
#
#                                     FDA_Section       CFR  \
# 0                            General Provisions     "1.1"
# 1                            General Provisions     "1.3"
# 2                            General Provisions     "1.4"
# 3                 General Labeling Requirements    "1.20"
# 4                 General Labeling Requirements    "1.21"
# ...                                         ...       ...
# 7911       Information in the custody of ONDCP.  "1402.3"
# 7912  Information classified by another agency.  "1402.4"
# 7913                          Appeal procedure.  "1402.5"
# 7914                                      Fees.  "1402.6"
# 7915                Suggestions and complaints.  "1402.7"
#
#                                     FDA_Subpart  \
# 0                                      General.
# 1                                  Definitions.
# 2                          Authority citations.
# 3      Presence of mandatory label information.
# 4             Failure to reveal material facts.
# ...                                         ...
# 7911       Information in the custody of ONDCP.
# 7912  Information classified by another agency.
# 7913                          Appeal procedure.
# 7914                                      Fees.
# 7915                Suggestions and complaints.
#
#                                         FDA_Description  \
# 0     (a) The provisions of regulations promulgated ...
# 1     (a)  Labeling   includes all written, printed,...
# 2     (a) For each part of its regulations, the Food...
# 3     In the regulations specified in 1.1(c) of this...
# 4     (a) Labeling of a food, drug, device, cosmetic...
# ...                                                 ...
# 7911  Information contained in ONDCP files and under...
# 7912  When a request is received for information tha...
# 7913  Appeals reviewed as a result of a denial will ...
# 7914  There will normally be no fees charged for the...
# 7915  Suggestions and complaints regarding the infor...
#
#                                        fda_desc_cleaned
# 0     provision regulation promulgated federal food ...
# 1     labeling includes written printed graphic matt...
# 2     part regulation food drug administration inclu...
# 3     regulation specified chapter term package mean...
# 4     labeling food drug device cosmetic tobacco pro...
# ...                                                 ...
# 7911  information contained ondcp file exclusive dec...
# 7912  request received information wa classified ano...
# 7913  appeal reviewed result denial routed director ...
# 7914  normally fee charged mandatory review classifi...
# 7915  suggestion complaint regarding information sec...
#
# [7916 rows x 6 columns]

# %%
# Read Health Canada data
df_hc = pd.read_csv('hc_crc.csv',engine='python')
hc_new = df_hc.copy()
hc_new.drop(['Level4'], axis = 1, inplace = True)# Drop these columns
hc_new['HC_Subpart'].fillna('Not Available', inplace = True) 
print(hc_new.shape)
hc_new.head()
# Out:
# (1860, 5)
#        HC_Chapter      HC_Section     HC_Subpart       CRC  \
# 0  Administration         General  Not Available  A.01.001
# 1  Administration         General  Not Available  A.01.002
# 2  Administration         General  Not Available  A.01.003
# 3  Administration  Interpretation  Not Available  A.01.010
# 4  Administration  Interpretation  Not Available  A.01.011
#
#                                       HC_Description
# 0  These Regulations may be cited as the  Food an...
# 1  These Regulations, where applicable, prescribe...
# 2                      [Repealed, SOR/94-289, s. 1]
# 3  In these Regulations acceptable method Act Foo...
# 4  The Minister shall, upon request, furnish copi...

# %%
hc_reserved = hc_new.loc[(hc_new['HC_Description'] == '[Reserved]')] 
print(hc_reserved.shape)
hc_reserved.head()
# Out:
# (86, 5)
#     HC_Chapter               HC_Section               HC_Subpart       CRC  \
# 162      Foods  Nutrient Content Claims  Nutrient Content Claims  B.01.514
# 163      Foods  Nutrient Content Claims  Nutrient Content Claims  B.01.515
# 164      Foods  Nutrient Content Claims  Nutrient Content Claims  B.01.516
# 165      Foods  Nutrient Content Claims  Nutrient Content Claims  B.01.517
# 166      Foods  Nutrient Content Claims  Nutrient Content Claims  B.01.518
#
#     HC_Description
# 162     [Reserved]
# 163     [Reserved]
# 164     [Reserved]
# 165     [Reserved]
# 166     [Reserved]

# %%
hc_new['counter']=''

for i in range(0,len(hc_new)):
    txt = hc_new['HC_Description'][i]
    x = re.search('^\[Repealed*', txt)
    if(x!=None):
        hc_new['counter'][i]=1
        
hc_repealed = hc_new.loc[hc_new['counter'] == 1]
hc_repealed.drop(['counter'], axis=1, inplace = True)
print(hc_repealed.shape)
hc_repealed.head()
# Out:
# (350, 5)
# /Users/sheetal/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         HC_Chapter                                         HC_Section  \
# 2   Administration                                            General
# 11  Administration                               Analysts; Inspectors
# 12  Administration                               Analysts; Inspectors
# 31  Administration  Labelling of Food and Drugs in Pressurized Con...
# 69           Foods                                            General
#
#        HC_Subpart        CRC                 HC_Description
# 2   Not Available   A.01.003  [Repealed, SOR/94-289, s. 1]
# 11  Not Available  A.01.020   [Repealed, SOR/81-935, s. 1]
# 12  Not Available   A.01.021  [Repealed, SOR/81-935, s. 1]
# 31  Not Available   A.01.064  [Repealed, SOR/93-243, s. 2]
# 69        General   B.01.034  [Repealed, SOR/88-559, s. 7]

# %%
hc_repealed_reserved = pd.concat([hc_repealed,hc_reserved])
print(hc_repealed_reserved.shape)
hc_repealed_reserved.head()
# Out:
# (436, 5)
#         HC_Chapter                                         HC_Section  \
# 2   Administration                                            General
# 11  Administration                               Analysts; Inspectors
# 12  Administration                               Analysts; Inspectors
# 31  Administration  Labelling of Food and Drugs in Pressurized Con...
# 69           Foods                                            General
#
#        HC_Subpart        CRC                 HC_Description
# 2   Not Available   A.01.003  [Repealed, SOR/94-289, s. 1]
# 11  Not Available  A.01.020   [Repealed, SOR/81-935, s. 1]
# 12  Not Available   A.01.021  [Repealed, SOR/81-935, s. 1]
# 31  Not Available   A.01.064  [Repealed, SOR/93-243, s. 2]
# 69        General   B.01.034  [Repealed, SOR/88-559, s. 7]

# %%
hc_new.drop(['counter'], axis=1, inplace = True)

cond = hc_new['CRC'].isin(hc_repealed_reserved['CRC'])
hc_new.drop(hc_new[cond].index, inplace = True)

print(hc_new.shape)
hc_new.head()
# Out:
# (1423, 5)
#        HC_Chapter      HC_Section     HC_Subpart       CRC  \
# 0  Administration         General  Not Available  A.01.001
# 1  Administration         General  Not Available  A.01.002
# 3  Administration  Interpretation  Not Available  A.01.010
# 4  Administration  Interpretation  Not Available  A.01.011
# 5  Administration  Interpretation  Not Available  A.01.012
#
#                                       HC_Description
# 0  These Regulations may be cited as the  Food an...
# 1  These Regulations, where applicable, prescribe...
# 3  In these Regulations acceptable method Act Foo...
# 4  The Minister shall, upon request, furnish copi...
# 5  The Minister shall, upon request, indicate tha...

# %%
hc_new.reset_index(drop=True, inplace=True)
print(hc_new.shape)
hc_new.isnull().sum()
# Out:
# (1423, 5)
# HC_Chapter        0
# HC_Section        0
# HC_Subpart        0
# CRC               0
# HC_Description    0
# dtype: int64

# %%
hc_new['hc_desc_cleaned'] = ''

# Pre-processing Health Canada Descriptions
lemmatizer = WordNetLemmatizer()
pattern1 = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
pattern2 = '[0-9]'
for i in range(0,len(hc_new)):
        sent_ref = hc_new.iloc[i]['HC_Description']
        sent_ref = sent_ref.lower() # convert to lower case
        word_list = nltk.word_tokenize(sent_ref)
        sent_ref = ' '.join([lemmatizer.lemmatize(w) for w in word_list]) # lemmatize
        sent_ref = re.sub(r'\([^)]*\)', '', sent_ref) # remove characters which are within parenthesis
        sent_ref = pattern1.sub('', sent_ref) # remove stopwords
        sent_ref = re.sub(r'[^\w\s]','',sent_ref) # remove spaces (new line, tabs etc)
        sent_ref = re.sub(pattern2, '', sent_ref) # remove numbers
        sent_ref = " ".join(sent_ref.split()) # remove whitespaces, if any
        hc_new['hc_desc_cleaned'][i] = sent_ref
        
hc_new
# Out:
#             HC_Chapter                                         HC_Section  \
# 0       Administration                                            General
# 1       Administration                                            General
# 2       Administration                                     Interpretation
# 3       Administration                                     Interpretation
# 4       Administration                                     Interpretation
# ...                ...                                                ...
# 1418  Restricted Drugs                                          Documents
# 1419  Restricted Drugs                                          Documents
# 1420  Restricted Drugs                                          Documents
# 1421  Restricted Drugs  Notification of Application for Order of Resto...
# 1422  Restricted Drugs  Notification of Application for Order of Resto...
#
#           HC_Subpart       CRC  \
# 0      Not Available  A.01.001
# 1      Not Available  A.01.002
# 2      Not Available  A.01.010
# 3      Not Available  A.01.011
# 4      Not Available  A.01.012
# ...              ...       ...
# 1418  Record Keeping  J.01.084
# 1419  Record Keeping  J.01.085
# 1420  Record Keeping  J.01.086
# 1421   Not Available  J.01.087
# 1422   Not Available  J.01.087
#
#                                          HC_Description  \
# 0     These Regulations may be cited as the  Food an...
# 1     These Regulations, where applicable, prescribe...
# 2     In these Regulations acceptable method Act Foo...
# 3     The Minister shall, upon request, furnish copi...
# 4     The Minister shall, upon request, indicate tha...
# ...                                                 ...
# 1418  Retention period A licensed dealer, a former l...
# 1419  Location The documents must be kept (a) in the...
# 1420  Quality of documents The documents must be com...
# 1421  Written notification (1) For the purpose of su...
# 1422  SCHEDULE (Sections J.01.001, J.01.002 and J.01...
#
#                                         hc_desc_cleaned
# 0             regulation may cited food drug regulation
# 1     regulation applicable prescribe standard compo...
# 2     regulation acceptable method act food drug act...
# 3     minister shall upon request furnish copy offic...
# 4     minister shall upon request indicate method ac...
# ...                                                 ...
# 1418  retention period licensed dealer former licens...
# 1419  location document must kept case licensed deal...
# 1420  quality document document must complete readil...
# 1421  written notification purpose subsection act no...
# 1422  schedule part following amphetamine salt deriv...
#
# [1423 rows x 6 columns]

# %%
# model embedding
embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens') # distilled BERT model

# %%
# define Corpus 
corpus = fda_new['fda_desc_cleaned'].to_list()
# corpus embedding
corpus_embeddings = embedder.encode(corpus, convert_to_tensor = True)

# %%
# define queries
queries = hc_new['hc_desc_cleaned'].to_list()

# %%
hc_new['matched'] = ''
hc_new['score']=''
hc_new['CFR']=''
hc_new['FDA_Chapter']=''
hc_new['FDA_Section']=''
hc_new['FDA_Subpart']=''
hc_new['FDA_Description']=''
hc_new['fda_desc_cleaned']=''

fda_new.head()
# Out:
#                        FDA_Chapter                    FDA_Section     CFR  \
# 0  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.1"
# 1  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.3"
# 2  GENERAL ENFORCEMENT REGULATIONS             General Provisions   "1.4"
# 3  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.20"
# 4  GENERAL ENFORCEMENT REGULATIONS  General Labeling Requirements  "1.21"
#
#                                 FDA_Subpart  \
# 0                                  General.
# 1                              Definitions.
# 2                      Authority citations.
# 3  Presence of mandatory label information.
# 4         Failure to reveal material facts.
#
#                                      FDA_Description  \
# 0  (a) The provisions of regulations promulgated ...
# 1  (a)  Labeling   includes all written, printed,...
# 2  (a) For each part of its regulations, the Food...
# 3  In the regulations specified in 1.1(c) of this...
# 4  (a) Labeling of a food, drug, device, cosmetic...
#
#                                     fda_desc_cleaned
# 0  provision regulation promulgated federal food ...
# 1  labeling includes written printed graphic matt...
# 2  part regulation food drug administration inclu...
# 3  regulation specified chapter term package mean...
# 4  labeling food drug device cosmetic tobacco pro...

# %%
threshold = float(0.5)

for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor = True)
    cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
    cos_scores = cos_scores.cpu()
    top_results = torch.topk(cos_scores, k=1)
    
    hc_new['score'][queries.index(query)] = float(top_results[0])
          
    if (float(top_results[0])) <= threshold:
        hc_new['matched'][queries.index(query)] = 0 # if score is less than threshold, it is not a match
        

    elif (float(top_results[0])) > threshold:
        hc_new['matched'][queries.index(query)] = 1
        hc_new['CFR'][queries.index(query)] = fda_new['CFR'][float(top_results[1])]
        hc_new['FDA_Chapter'][queries.index(query)] = fda_new['FDA_Chapter'][float(top_results[1])]
        hc_new['FDA_Section'][queries.index(query)] = fda_new['FDA_Section'][float(top_results[1])]
        hc_new['FDA_Subpart'][queries.index(query)] = fda_new['FDA_Subpart'][float(top_results[1])]
        hc_new['FDA_Description'][queries.index(query)] = fda_new['FDA_Description'][float(top_results[1])]
        hc_new['fda_desc_cleaned'][queries.index(query)] = fda_new['fda_desc_cleaned'][float(top_results[1])]

# %%
hc_new.rename(columns = {'CRC':'HC_Code',
                         'CFR':'FDA_Code'}, inplace = True)

# %%
hc_new.to_csv(r'hc_matched_new.csv',index = False)

# %%
print(hc_new.shape)
hc_new.head()
# Out:
# (1423, 14)
#        HC_Chapter      HC_Section     HC_Subpart   HC_Code  \
# 0  Administration         General  Not Available  A.01.001
# 1  Administration         General  Not Available  A.01.002
# 2  Administration  Interpretation  Not Available  A.01.010
# 3  Administration  Interpretation  Not Available  A.01.011
# 4  Administration  Interpretation  Not Available  A.01.012
#
#                                       HC_Description  \
# 0  These Regulations may be cited as the  Food an...
# 1  These Regulations, where applicable, prescribe...
# 2  In these Regulations acceptable method Act Foo...
# 3  The Minister shall, upon request, furnish copi...
# 4  The Minister shall, upon request, indicate tha...
#
#                                      hc_desc_cleaned matched     score  \
# 0          regulation may cited food drug regulation       1  0.758713
# 1  regulation applicable prescribe standard compo...       1  0.764611
# 2  regulation acceptable method act food drug act...       1  0.769075
# 3  minister shall upon request furnish copy offic...       1  0.637533
# 4  minister shall upon request indicate method ac...       1  0.613881
#
#      FDA_Code                                        FDA_Chapter  \
# 0    "56.105"                    GENERAL ENFORCEMENT REGULATIONS
# 1  "184.1851"  DIRECT FOOD SUBSTANCES AFFIRMED AS GENERALLY R...
# 2     "200.7"                                            GENERAL
# 3   "117.320"  CURRENT GOOD MANUFACTURING PRACTICE, HAZARD AN...
# 4   "1316.55"  ADMINISTRATIVE FUNCTIONS, PRACTICES, AND PROCE...
#
#                                          FDA_Section  \
# 0                                 General Provisions
# 1    Listing of Specific Substances Affirmed as GRAS
# 2                                 General Provisions
# 3  Requirements Applying to Records That Must Be ...
# 4                            Administrative Hearings
#
#                                          FDA_Subpart  \
# 0                         Waiver of IRB requirement.
# 1                                   Stearyl citrate.
# 2  Supplying pharmacists with indications and dos...
# 3                  Requirements for official review.
# 4                                 Prehearing ruling.
#
#                                      FDA_Description  \
# 0  On the application of a sponsor or sponsor-inv...
# 1  (a) Stearyl citrate is a mixture of the mono-,...
# 2  There are presently no regulations under the F...
# 3  All records required by this part must be made...
# 4  The presiding officer may have the prehearing ...
#
#                                     fda_desc_cleaned
# 0  application sponsor sponsorinvestigator food d...
# 1  stearyl citrate mixture mono di tristearyl est...
# 2  presently regulation federal food drug cosmeti...
# 3  record required part must made promptly availa...
# 4  presiding officer may prehearing conference re...
